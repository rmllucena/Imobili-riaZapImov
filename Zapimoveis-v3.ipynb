# %%
NovaIguaçu = "https://www.zapimoveis.com.br/venda/imoveis/rj+nova-iguacu/?pagina={}"
Copacabana = "https://www.zapimoveis.com.br/venda/imoveis/rj+rio-de-janeiro+zona-sul+copacabana/?pagina={}&onde=,Rio%20de%20Janeiro,Rio%20de%20Janeiro,Zona%20Sul,Copacabana,,,neighborhood,BR%3ERio%20de%20Janeiro%3ENULL%3ERio%20de%20Janeiro%3EZona%20Sul%3ECopacabana,-22.969442,-43.186845&transacao=Venda&tipo=Im%C3%B3vel%20usado"
CaboFrio = "https://www.zapimoveis.com.br/venda/imoveis/rj+cabo-frio/?pagina={}&onde=,Rio%20de%20Janeiro,Cabo%20Frio,,,,,city,BR%3ERio%20de%20Janeiro%3ENULL%3ECabo%20Frio,-19.394665,-40.065264&transacao=Venda&tipo=Im%C3%B3vel%20usado"

# %%
import win32com.client

# %%
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from pandas import DataFrame
import openpyxl as xl
from openpyxl import load_workbook
from openpyxl import Workbook
from pathlib import Path
import os
import win32com.client

# %%
Local = "NovaIguaçu"
num = 1

while num <= 4:
        
    linkzapvenda = "https://www.zapimoveis.com.br/venda/imoveis/rj+nova-iguacu/?pagina={}".format(num)

    option = webdriver.ChromeOptions()
    #option.add_argument('headless') 
    option.add_argument("enable-automation");
    option.add_argument("--window-size=1920,1080");
    option.add_argument("--no-sandbox");
    option.add_argument("--disable-extensions");
    option.add_argument("--dns-prefetch-disable");
    option.add_argument("--disable-gpu");
    option.add_argument("user-agent=whatever you want") #https://stackoverflow.com/questions/29916054/change-user-agent-for-selenium-web-driver
    option.add_argument('--ignore-certificate-errors')
    option.add_argument("--test-type");
    driver = webdriver.Chrome(r"C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\chromedriver.exe",options=option);

    #main_window = driver.window_handles[0]
    #new_window = driver.window_handles[1]
    #driver.switch_to_window(new_window)

    driver.get(linkzapvenda)

    time.sleep(5)

    #html = driver.page_source



    a = driver.find_element_by_css_selector('body').text
    #print(a)

    lista = a.split("\n")[73:-56]

    imoveis = []
    listaimoveis = []
    listaimoveistemp = []
    ordem = 0

    for x in range(len(lista)):
        if lista[x] == "Ligar":     

            imoveis.append([lista[x],x,ordem])

            y = -ordem
            while y < 0:
                listaimoveistemp.append(lista[x+y])
                y += 1
            else:
                pass


            listaimoveis.append(listaimoveistemp)
            listaimoveistemp = []

            ordem = 0
        else:
            ordem += 1
            
    driver.close() 

    imoveis
    df = DataFrame(listaimoveis)

    df.to_excel(r"C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\Base_{}.xlsx".format(num))
    #df
    
    print(num)

    num += 1
# Out:
# 1
# 2
# 3
# 4

# %%
imoveis
# Out:
# [['Ligar', 11, 11],
#  ['Ligar', 21, 9],
#  ['Ligar', 33, 11],
#  ['Ligar', 45, 11],
#  ['Ligar', 57, 11],
#  ['Ligar', 67, 9],
#  ['Ligar', 78, 10],
#  ['Ligar', 94, 15],
#  ['Ligar', 104, 9],
#  ['Ligar', 119, 14],
#  ['Ligar', 131, 11],
#  ['Ligar', 143, 11],
#  ['Ligar', 153, 9],
#  ['Ligar', 167, 13],
#  ['Ligar', 177, 9],
#  ['Ligar', 188, 10],
#  ['Ligar', 200, 11],
#  ['Ligar', 212, 11],
#  ['Ligar', 224, 11],
#  ['Ligar', 235, 10],
#  ['Ligar', 246, 10],
#  ['Ligar', 257, 10]]

# %%
len(lista)
# Out:
# 262

# %%
listaimoveis
# Out:
# [['Mensagem',
#   'pronto para morar',
#   'R$ 79.900',
#   'INSIGHT OFFICE | Taquara | 17 a 25m².',
#   '',
#   'Empreendimento comercial no melhor da Taquara. Valorização, mobilidade e inteligência de projeto em um só lugar!',
#   '',
#   'Galeria com mix...',
#   'mais',
#   'Avenida Nelson Cardoso, Taquara',
#   '17 - 25 m²'],
#  ['Mensagem',
#   'super destaque',
#   'R$ 148.000.000',
#   'condomínioR$ 405 IPTU R$ 67',
#   'Sala com 24 m2, no Centro de Nova Iguaçu, empreendimento Top Commerce, em frente ao Top Shopping. Venha conhecer. Agende uma visita. Tels. (21) 2767.0127 e (21) 97030.0124, este co...',
#   'mais',
#   'Avenida Governador Roberto Silveira, Centro',
#   '24 m²',
#   '1'],
#  ['Mensagem',
#   'super destaque',
#   'R$ 1.300.000',
#   'condomínioR$ 1.255 IPTU R$ 2.248',
#   'Esse é o apartamento ideal para quem busca conforto e o máximo de qualidade, se é para viver no melhor condomínio clube da região, em uma planta com 137m² você precisa também de um...',
#   'mais',
#   'Centro, Nova Iguaçu',
#   '137 m²',
#   '3',
#   '3',
#   '3'],
#  ['Mensagem',
#   'super destaque',
#   'R$ 499.700',
#   'condomínioR$ 711',
#   'Condomínio de alto padrão com apartamento de 3 quartos, sendo 1 suíte, varanda e 2 vagas na garagem, e lazer completo. Toda exclusividade em apenas 1 bloco. Conforto e segurança co...',
#   'mais',
#   'Rua Luís de Camões, da Luz',
#   '84 m²',
#   '3',
#   '1',
#   '2'],
#  ['Mensagem',
#   'destaque',
#   'R$ 399.000',
#   'Casa Linear espaçosa, 2 quartos, Sala , Cozinha 2 ambientes , Banheiro , garagem para 2 carros, área de serviço , Piscina desativada. 1 quarto e banheiro externo .',
#   'Metragem:',
#   'mais',
#   'Avenida Baltimore, Jardim Esplanada',
#   '100 m²',
#   '3',
#   '2',
#   '2'],
#  ['Mensagem',
#   'R$ 530.000',
#   'O apartamento no bairro Palmeiras tem 85 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Possui academia, espaço gourmet, área verde de jardim, parquinho infantil, espa...',
#   'mais',
#   'Rua Afrânio Peixoto, Palmeiras',
#   '85 m²',
#   '3',
#   '1',
#   '2'],
#  ['Mensagem',
#   'R$ 440.000',
#   'condomínioR$ 500',
#   'Condomínio de alto padrão com apartamentos de 2 ou 3 quartos e lazer completo. Toda exclusividade em apenas 1 bloco. Conforto e segurança com um charme padrão “Golden” da Visione....',
#   'mais',
#   'Rua Luís de Camões, Centro',
#   '66 m²',
#   '3',
#   '1',
#   '2'],
#  ['Mensagem',
#   'R$ 275.000',
#   'Casas Duplex, com 2 Quartos sendo 1 Suíte, Sala, Cozinha, Banheiro, 1 Lavabo, Área de Serviço e Garagem Coberta',
#   '',
#   'Metragem:',
#   '85 Mts²',
#   '',
#   'Localização',
#   'Rua Tertuliano P...',
#   'mais',
#   'Rua Tertuliano Pimenta, Vila Sao Jorge',
#   '80 m²',
#   '2',
#   '1',
#   '3'],
#  ['Mensagem',
#   'R$ 150.000',
#   'Residência linear, sala espaçosa, 02 quartos, sendo 01 suíte, banheiro social com box, área de serviço, 02 vagas de garagem, quintal na frente e fundos, quiosque com churrasqueira,...',
#   'mais',
#   'Lagoinha, Nova Iguaçu',
#   '100 m²',
#   '2',
#   '2',
#   '3'],
#  ['Mensagem',
#   'R$ 195.112',
#   'condomínioR$ 250 IPTU R$ 57',
#   'Vendo Apartamento em Nova Iguaçu, Bairro da Luz, 2 Quartos com Varanda - Condomínio Conceito Residencial',
#   '',
#   'Excelente para morar, perfeito para investir!',
#   '',
#   '- Apartamento c...',
#   'mais',
#   'Rua Otávio Tarquino, Luz',
#   '47 m²',
#   '2',
#   '1',
#   '1'],
#  ['Mensagem',
#   'R$ 694.000',
#   'condomínioR$ 1.000 IPTU R$ 500',
#   'Temos unidades de 2 quartos, 3, 4 e uma cobertura.',
#   'Condomínio de altíssimo padrão que marcou a história do mercado imobiliário de Nova Iguaçu e da Baixada Fluminense. Todo luxo...',
#   'mais',
#   'Rua Afrânio Peixoto, Centro',
#   '90 m²',
#   '4',
#   '3',
#   '4'],
#  ['Mensagem',
#   'R$ 235.000',
#   'condomínioR$ 380',
#   'Vendo apartamento no Condomínio Vitória com 2 quartos. Armário nos quartos e cozinha, área de serviço, aquecedor a gás, banheiro com blindex e armário.',
#   'Aceita financiamento. Op...',
#   'mais',
#   'Rua Doutor Barros Júnior, Rancho Novo',
#   '56 m²',
#   '2',
#   '1',
#   '1'],
#  ['Mensagem',
#   'R$ 369.000',
#   'Mais um lançamento da Visione. Um lindo Apartamento no bairro de Nova Iguaçu, com 67 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Vai possui um linda e espetacular i...',
#   'mais',
#   'Rua Doutor Barros Júnior, Centro',
#   '67 m²',
#   '3',
#   '1',
#   '2'],
#  ['Mensagem',
#   'R$ 280.000',
#   'Casa Independente e frente de rua em Nova Iguaçu - Bairro Santa Eugenia',
#   '',
#   'PONTO DE REFERENCIA: próximo da rua da garagem santa eugenia, 10 ruas depois do mercado Extra',
#   '',
#   '...',
#   'mais',
#   'Rua Jacutinga, Centro',
#   '250 m²',
#   '3',
#   '2',
#   '1'],
#  ['Mensagem',
#   'R$ 549.000',
#   'O apartamento no bairro Palmeiras tem 85 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Possui academia, espaço gourmet, área verde de jardim, parquinho infantil, espa...',
#   'mais',
#   'Rua Afrânio Peixoto, Palmeiras',
#   '85 m²',
#   '3',
#   '2',
#   '2'],
#  ['Mensagem',
#   'R$ 420.000',
#   'condomínioR$ 450 IPTU R$ 95',
#   'Apartamento a venda com varanda,2 quartos, uma suite,sala,cozinha americana,banheiro social, área de serviço e uma vaga de garagem . O prédio possui 2 piscinas,sauna,spa,academia ,...',
#   'mais',
#   'Rua Comendador Soares, Centro',
#   '63 m²',
#   '2',
#   '1',
#   '2'],
#  ['Mensagem',
#   'destaque',
#   'R$ 430.000',
#   'IPTU R$ 120',
#   'Casa com 3 quartos e 1 suíte em Nova Iguaçu Santa Eugênia, com 150 m², Super espaçosa, com quartos amplos, sala e cozinha bem grande, copa separada, área de serviço muito boa, vaga...',
#   'mais',
#   'Rua Aderbal da Fonseca, Santa Eugênia',
#   '150 m²',
#   '3',
#   '2',
#   '2'],
#  ['Mensagem',
#   'destaque',
#   'R$ 300.000',
#   'condomínioR$ 465 IPTU R$ 60',
#   'Apartamento próximo a faculdade Unig, com 02 quartos, sala, cozinha banheiro, garagem, elevador. Condomínio possui piscina, churrasqueira, espaço KIDS, salão de festas, quadra poli...',
#   'mais',
#   'da Luz, Nova Iguaçu',
#   '70 m²',
#   '2',
#   '1',
#   '1'],
#  ['Mensagem',
#   'destaque',
#   'R$ 320.000',
#   'condomínioR$ 530 IPTU R$ 120',
#   'Excelente apartamento à venda no Centro de Nova Iguaçu (Condomínio FLORAE). Com 65 m²; 2 quartos (sendo 1 suíte); Sol da manhã; varanda; 1 vaga de garagem; armários planejados na c...',
#   'mais',
#   'Avenida Doutor Mário Guimarães, Centro',
#   '65 m²',
#   '2',
#   '1',
#   '2'],
#  ['Mensagem',
#   'R$ 280.000',
#   'IPTU R$ 50',
#   'Casa com 2 suítes na Posse Nova Iguaçu. 86 m². Novíssima, Com um acabamento impecável. Toda em porcelanato, com portão eletrônico. Aceita financiamento. Ligue e saiba mais informaç...',
#   'mais',
#   'Rua F, Posse',
#   '86 m²',
#   '2',
#   '1',
#   '3'],
#  ['Mensagem',
#   'destaque',
#   'R$ 657.000',
#   'O apartamento no bairro Palmeiras tem 97 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Possui academia, espaço gourmet, área verde de jardim, parquinho infantil, espa...',
#   'mais',
#   'Rua Afrânio Peixoto, Palmeiras',
#   '97 m²',
#   '3',
#   '2',
#   '2'],
#  ['Mensagem',
#   'R$ 270.000',
#   'condomínioR$ 420 IPTU R$ 60',
#   'Imóvel próximo de padaria, mercado, hortifruti, escola, transporte público na porta. O apartamento está equipado com ar condicionado nos quartos, cooktop, mesa de jantar, armário d...',
#   'mais',
#   'Rua Capitão Edmundo Soares, Caonze',
#   '60 m²',
#   '2',
#   '2',
#   '1']]

# %%
df
# Out:
#           0                  1   \
# 0   Mensagem  pronto para morar
# 1   Mensagem     super destaque
# 2   Mensagem     super destaque
# 3   Mensagem     super destaque
# 4   Mensagem           destaque
# 5   Mensagem         R$ 530.000
# 6   Mensagem         R$ 440.000
# 7   Mensagem         R$ 275.000
# 8   Mensagem         R$ 150.000
# 9   Mensagem         R$ 195.112
# 10  Mensagem         R$ 694.000
# 11  Mensagem         R$ 235.000
# 12  Mensagem         R$ 369.000
# 13  Mensagem         R$ 280.000
# 14  Mensagem         R$ 549.000
# 15  Mensagem         R$ 420.000
# 16  Mensagem           destaque
# 17  Mensagem           destaque
# 18  Mensagem           destaque
# 19  Mensagem         R$ 280.000
# 20  Mensagem           destaque
# 21  Mensagem         R$ 270.000
#
#                                                    2   \
# 0                                           R$ 79.900
# 1                                      R$ 148.000.000
# 2                                        R$ 1.300.000
# 3                                          R$ 499.700
# 4                                          R$ 399.000
# 5   O apartamento no bairro Palmeiras tem 85 metro...
# 6                                    condomínioR$ 500
# 7   Casas Duplex, com 2 Quartos sendo 1 Suíte, Sal...
# 8   Residência linear, sala espaçosa, 02 quartos, ...
# 9                         condomínioR$ 250 IPTU R$ 57
# 10                     condomínioR$ 1.000 IPTU R$ 500
# 11                                   condomínioR$ 380
# 12  Mais um lançamento da Visione. Um lindo Aparta...
# 13  Casa Independente e frente de rua em Nova Igua...
# 14  O apartamento no bairro Palmeiras tem 85 metro...
# 15                        condomínioR$ 450 IPTU R$ 95
# 16                                         R$ 430.000
# 17                                         R$ 300.000
# 18                                         R$ 320.000
# 19                                         IPTU R$ 50
# 20                                         R$ 657.000
# 21                        condomínioR$ 420 IPTU R$ 60
#
#                                                    3   \
# 0               INSIGHT OFFICE | Taquara | 17 a 25m².
# 1                         condomínioR$ 405 IPTU R$ 67
# 2                    condomínioR$ 1.255 IPTU R$ 2.248
# 3                                    condomínioR$ 711
# 4   Casa Linear espaçosa, 2 quartos, Sala , Cozinh...
# 5                                                mais
# 6   Condomínio de alto padrão com apartamentos de ...
# 7
# 8                                                mais
# 9   Vendo Apartamento em Nova Iguaçu, Bairro da Lu...
# 10  Temos unidades de 2 quartos, 3, 4 e uma cobert...
# 11  Vendo apartamento no Condomínio Vitória com 2 ...
# 12                                               mais
# 13
# 14                                               mais
# 15  Apartamento a venda com varanda,2 quartos, uma...
# 16                                        IPTU R$ 120
# 17                        condomínioR$ 465 IPTU R$ 60
# 18                       condomínioR$ 530 IPTU R$ 120
# 19  Casa com 2 suítes na Posse Nova Iguaçu. 86 m²....
# 20  O apartamento no bairro Palmeiras tem 97 metro...
# 21  Imóvel próximo de padaria, mercado, hortifruti...
#
#                                                    4   \
# 0
# 1   Sala com 24 m2, no Centro de Nova Iguaçu, empr...
# 2   Esse é o apartamento ideal para quem busca con...
# 3   Condomínio de alto padrão com apartamento de 3...
# 4                                           Metragem:
# 5                      Rua Afrânio Peixoto, Palmeiras
# 6                                                mais
# 7                                           Metragem:
# 8                               Lagoinha, Nova Iguaçu
# 9
# 10  Condomínio de altíssimo padrão que marcou a hi...
# 11                        Aceita financiamento. Op...
# 12                   Rua Doutor Barros Júnior, Centro
# 13  PONTO DE REFERENCIA: próximo da rua da garagem...
# 14                     Rua Afrânio Peixoto, Palmeiras
# 15                                               mais
# 16  Casa com 3 quartos e 1 suíte em Nova Iguaçu Sa...
# 17  Apartamento próximo a faculdade Unig, com 02 q...
# 18  Excelente apartamento à venda no Centro de Nov...
# 19                                               mais
# 20                                               mais
# 21                                               mais
#
#                                                    5   \
# 0   Empreendimento comercial no melhor da Taquara....
# 1                                                mais
# 2                                                mais
# 3                                                mais
# 4                                                mais
# 5                                               85 m²
# 6                          Rua Luís de Camões, Centro
# 7                                             85 Mts²
# 8                                              100 m²
# 9       Excelente para morar, perfeito para investir!
# 10                                               mais
# 11                                               mais
# 12                                              67 m²
# 13
# 14                                              85 m²
# 15                      Rua Comendador Soares, Centro
# 16                                               mais
# 17                                               mais
# 18                                               mais
# 19                                       Rua F, Posse
# 20                     Rua Afrânio Peixoto, Palmeiras
# 21                 Rua Capitão Edmundo Soares, Caonze
#
#                                              6                   7   \
# 0                                                Galeria com mix...
# 1   Avenida Governador Roberto Silveira, Centro               24 m²
# 2                           Centro, Nova Iguaçu              137 m²
# 3                    Rua Luís de Camões, da Luz               84 m²
# 4           Avenida Baltimore, Jardim Esplanada              100 m²
# 5                                             3                   1
# 6                                         66 m²                   3
# 7                                                       Localização
# 8                                             2                   2
# 9                                                - Apartamento c...
# 10                  Rua Afrânio Peixoto, Centro               90 m²
# 11        Rua Doutor Barros Júnior, Rancho Novo               56 m²
# 12                                            3                   1
# 13                                          ...                mais
# 14                                            3                   2
# 15                                        63 m²                   2
# 16        Rua Aderbal da Fonseca, Santa Eugênia              150 m²
# 17                          da Luz, Nova Iguaçu               70 m²
# 18       Avenida Doutor Mário Guimarães, Centro               65 m²
# 19                                        86 m²                   2
# 20                                        97 m²                   3
# 21                                        60 m²                   2
#
#                        8                                9   \
# 0                    mais  Avenida Nelson Cardoso, Taquara
# 1                       1                             None
# 2                       3                                3
# 3                       3                                1
# 4                       3                                2
# 5                       2                             None
# 6                       1                                2
# 7     Rua Tertuliano P...                             mais
# 8                       3                             None
# 9                    mais         Rua Otávio Tarquino, Luz
# 10                      4                                3
# 11                      2                                1
# 12                      2                             None
# 13  Rua Jacutinga, Centro                           250 m²
# 14                      2                             None
# 15                      1                                2
# 16                      3                                2
# 17                      2                                1
# 18                      2                                1
# 19                      1                                3
# 20                      2                                2
# 21                      2                                1
#
#                                         10     11    12    13    14
# 0                               17 - 25 m²   None  None  None  None
# 1                                     None   None  None  None  None
# 2                                        3   None  None  None  None
# 3                                        2   None  None  None  None
# 4                                        2   None  None  None  None
# 5                                     None   None  None  None  None
# 6                                     None   None  None  None  None
# 7   Rua Tertuliano Pimenta, Vila Sao Jorge  80 m²     2     1     3
# 8                                     None   None  None  None  None
# 9                                    47 m²      2     1     1  None
# 10                                       4   None  None  None  None
# 11                                       1   None  None  None  None
# 12                                    None   None  None  None  None
# 13                                       3      2     1  None  None
# 14                                    None   None  None  None  None
# 15                                    None   None  None  None  None
# 16                                       2   None  None  None  None
# 17                                       1   None  None  None  None
# 18                                       2   None  None  None  None
# 19                                    None   None  None  None  None
# 20                                    None   None  None  None  None
# 21                                    None   None  None  None  None

# %%
lista
# Out:
# ['Mensagem',
#  'pronto para morar',
#  'R$ 79.900',
#  'INSIGHT OFFICE | Taquara | 17 a 25m².',
#  '',
#  'Empreendimento comercial no melhor da Taquara. Valorização, mobilidade e inteligência de projeto em um só lugar!',
#  '',
#  'Galeria com mix...',
#  'mais',
#  'Avenida Nelson Cardoso, Taquara',
#  '17 - 25 m²',
#  'Ligar',
#  'Mensagem',
#  'super destaque',
#  'R$ 148.000.000',
#  'condomínioR$ 405 IPTU R$ 67',
#  'Sala com 24 m2, no Centro de Nova Iguaçu, empreendimento Top Commerce, em frente ao Top Shopping. Venha conhecer. Agende uma visita. Tels. (21) 2767.0127 e (21) 97030.0124, este co...',
#  'mais',
#  'Avenida Governador Roberto Silveira, Centro',
#  '24 m²',
#  '1',
#  'Ligar',
#  'Mensagem',
#  'super destaque',
#  'R$ 1.300.000',
#  'condomínioR$ 1.255 IPTU R$ 2.248',
#  'Esse é o apartamento ideal para quem busca conforto e o máximo de qualidade, se é para viver no melhor condomínio clube da região, em uma planta com 137m² você precisa também de um...',
#  'mais',
#  'Centro, Nova Iguaçu',
#  '137 m²',
#  '3',
#  '3',
#  '3',
#  'Ligar',
#  'Mensagem',
#  'super destaque',
#  'R$ 499.700',
#  'condomínioR$ 711',
#  'Condomínio de alto padrão com apartamento de 3 quartos, sendo 1 suíte, varanda e 2 vagas na garagem, e lazer completo. Toda exclusividade em apenas 1 bloco. Conforto e segurança co...',
#  'mais',
#  'Rua Luís de Camões, da Luz',
#  '84 m²',
#  '3',
#  '1',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'destaque',
#  'R$ 399.000',
#  'Casa Linear espaçosa, 2 quartos, Sala , Cozinha 2 ambientes , Banheiro , garagem para 2 carros, área de serviço , Piscina desativada. 1 quarto e banheiro externo .',
#  'Metragem:',
#  'mais',
#  'Avenida Baltimore, Jardim Esplanada',
#  '100 m²',
#  '3',
#  '2',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'R$ 530.000',
#  'O apartamento no bairro Palmeiras tem 85 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Possui academia, espaço gourmet, área verde de jardim, parquinho infantil, espa...',
#  'mais',
#  'Rua Afrânio Peixoto, Palmeiras',
#  '85 m²',
#  '3',
#  '1',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'R$ 440.000',
#  'condomínioR$ 500',
#  'Condomínio de alto padrão com apartamentos de 2 ou 3 quartos e lazer completo. Toda exclusividade em apenas 1 bloco. Conforto e segurança com um charme padrão “Golden” da Visione....',
#  'mais',
#  'Rua Luís de Camões, Centro',
#  '66 m²',
#  '3',
#  '1',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'R$ 275.000',
#  'Casas Duplex, com 2 Quartos sendo 1 Suíte, Sala, Cozinha, Banheiro, 1 Lavabo, Área de Serviço e Garagem Coberta',
#  '',
#  'Metragem:',
#  '85 Mts²',
#  '',
#  'Localização',
#  'Rua Tertuliano P...',
#  'mais',
#  'Rua Tertuliano Pimenta, Vila Sao Jorge',
#  '80 m²',
#  '2',
#  '1',
#  '3',
#  'Ligar',
#  'Mensagem',
#  'R$ 150.000',
#  'Residência linear, sala espaçosa, 02 quartos, sendo 01 suíte, banheiro social com box, área de serviço, 02 vagas de garagem, quintal na frente e fundos, quiosque com churrasqueira,...',
#  'mais',
#  'Lagoinha, Nova Iguaçu',
#  '100 m²',
#  '2',
#  '2',
#  '3',
#  'Ligar',
#  'Mensagem',
#  'R$ 195.112',
#  'condomínioR$ 250 IPTU R$ 57',
#  'Vendo Apartamento em Nova Iguaçu, Bairro da Luz, 2 Quartos com Varanda - Condomínio Conceito Residencial',
#  '',
#  'Excelente para morar, perfeito para investir!',
#  '',
#  '- Apartamento c...',
#  'mais',
#  'Rua Otávio Tarquino, Luz',
#  '47 m²',
#  '2',
#  '1',
#  '1',
#  'Ligar',
#  'Mensagem',
#  'R$ 694.000',
#  'condomínioR$ 1.000 IPTU R$ 500',
#  'Temos unidades de 2 quartos, 3, 4 e uma cobertura.',
#  'Condomínio de altíssimo padrão que marcou a história do mercado imobiliário de Nova Iguaçu e da Baixada Fluminense. Todo luxo...',
#  'mais',
#  'Rua Afrânio Peixoto, Centro',
#  '90 m²',
#  '4',
#  '3',
#  '4',
#  'Ligar',
#  'Mensagem',
#  'R$ 235.000',
#  'condomínioR$ 380',
#  'Vendo apartamento no Condomínio Vitória com 2 quartos. Armário nos quartos e cozinha, área de serviço, aquecedor a gás, banheiro com blindex e armário.',
#  'Aceita financiamento. Op...',
#  'mais',
#  'Rua Doutor Barros Júnior, Rancho Novo',
#  '56 m²',
#  '2',
#  '1',
#  '1',
#  'Ligar',
#  'Mensagem',
#  'R$ 369.000',
#  'Mais um lançamento da Visione. Um lindo Apartamento no bairro de Nova Iguaçu, com 67 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Vai possui um linda e espetacular i...',
#  'mais',
#  'Rua Doutor Barros Júnior, Centro',
#  '67 m²',
#  '3',
#  '1',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'R$ 280.000',
#  'Casa Independente e frente de rua em Nova Iguaçu - Bairro Santa Eugenia',
#  '',
#  'PONTO DE REFERENCIA: próximo da rua da garagem santa eugenia, 10 ruas depois do mercado Extra',
#  '',
#  '...',
#  'mais',
#  'Rua Jacutinga, Centro',
#  '250 m²',
#  '3',
#  '2',
#  '1',
#  'Ligar',
#  'Mensagem',
#  'R$ 549.000',
#  'O apartamento no bairro Palmeiras tem 85 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Possui academia, espaço gourmet, área verde de jardim, parquinho infantil, espa...',
#  'mais',
#  'Rua Afrânio Peixoto, Palmeiras',
#  '85 m²',
#  '3',
#  '2',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'R$ 420.000',
#  'condomínioR$ 450 IPTU R$ 95',
#  'Apartamento a venda com varanda,2 quartos, uma suite,sala,cozinha americana,banheiro social, área de serviço e uma vaga de garagem . O prédio possui 2 piscinas,sauna,spa,academia ,...',
#  'mais',
#  'Rua Comendador Soares, Centro',
#  '63 m²',
#  '2',
#  '1',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'destaque',
#  'R$ 430.000',
#  'IPTU R$ 120',
#  'Casa com 3 quartos e 1 suíte em Nova Iguaçu Santa Eugênia, com 150 m², Super espaçosa, com quartos amplos, sala e cozinha bem grande, copa separada, área de serviço muito boa, vaga...',
#  'mais',
#  'Rua Aderbal da Fonseca, Santa Eugênia',
#  '150 m²',
#  '3',
#  '2',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'destaque',
#  'R$ 300.000',
#  'condomínioR$ 465 IPTU R$ 60',
#  'Apartamento próximo a faculdade Unig, com 02 quartos, sala, cozinha banheiro, garagem, elevador. Condomínio possui piscina, churrasqueira, espaço KIDS, salão de festas, quadra poli...',
#  'mais',
#  'da Luz, Nova Iguaçu',
#  '70 m²',
#  '2',
#  '1',
#  '1',
#  'Ligar',
#  'Mensagem',
#  'destaque',
#  'R$ 320.000',
#  'condomínioR$ 530 IPTU R$ 120',
#  'Excelente apartamento à venda no Centro de Nova Iguaçu (Condomínio FLORAE). Com 65 m²; 2 quartos (sendo 1 suíte); Sol da manhã; varanda; 1 vaga de garagem; armários planejados na c...',
#  'mais',
#  'Avenida Doutor Mário Guimarães, Centro',
#  '65 m²',
#  '2',
#  '1',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'R$ 280.000',
#  'IPTU R$ 50',
#  'Casa com 2 suítes na Posse Nova Iguaçu. 86 m². Novíssima, Com um acabamento impecável. Toda em porcelanato, com portão eletrônico. Aceita financiamento. Ligue e saiba mais informaç...',
#  'mais',
#  'Rua F, Posse',
#  '86 m²',
#  '2',
#  '1',
#  '3',
#  'Ligar',
#  'Mensagem',
#  'destaque',
#  'R$ 657.000',
#  'O apartamento no bairro Palmeiras tem 97 metros quadrados com 3 quartos sendo 1 suite e 2 banheiros. Possui academia, espaço gourmet, área verde de jardim, parquinho infantil, espa...',
#  'mais',
#  'Rua Afrânio Peixoto, Palmeiras',
#  '97 m²',
#  '3',
#  '2',
#  '2',
#  'Ligar',
#  'Mensagem',
#  'R$ 270.000',
#  'condomínioR$ 420 IPTU R$ 60',
#  'Imóvel próximo de padaria, mercado, hortifruti, escola, transporte público na porta. O apartamento está equipado com ar condicionado nos quartos, cooktop, mesa de jantar, armário d...',
#  'mais',
#  'Rua Capitão Edmundo Soares, Caonze',
#  '60 m²',
#  '2',
#  '2',
#  '1',
#  'Ligar',
#  'Mensagem',
#  '6',
#  '7',
#  '8']

# %%
os.system(r'C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\Dataprep-Novoformato_Macro.xlsm')
# Out:
# 0

# %%
df.to_excel(r'C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\OutputPython_Macro.xlsm', sheet_name='Plan1', index=False)
time.sleep(3)
os.system(r'C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\Dataprep-Novoformato_Macro.xlsm')
time.sleep(3)
os.system(r'C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\OutputPython_Macro.xlsm')

# %%
df.to_excel(r'C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\OutputPython.xlsx', sheet_name='Plan1', index=False)

xl = Dispatch('Excel.Application')
wb = xl.Workbook.open(r'C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\OutputPython.xlsx')
# do some stuff
wb.close(True) # save the workbook

# %%
xl = win32com.client.DispatchEx("Excel.Application")
wb = xl.workbooks.open(r'C:\Users\Romulo\Programação\Python\Scripts\Imobiliaria\Dataprep\OutputPython.xlsx')
#wb.close
#xl.Quit()
